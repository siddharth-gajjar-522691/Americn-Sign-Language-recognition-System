# %%
# !pip install tensorflow==2.8 tensorflow-gpu==2.8 opencv-python mediapipe scikit-learn matplotlib  protobuf==3.20.1

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf

# %%
#Importing the Mediapipe library and its holistic model for holistic human pose estimation, along with drawing utilities for visualization.

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
#A function to perform Mediapipe detection on an image using a specified model, converting the image from BGR to RGB for processing, 
#making predictions, and then converting it back from RGB to BGR before returning the result alongside the detection results.

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
#A function to draw landmarks on the image using results from Mediapipe detection, including facial, pose, left hand, and right hand 
#landmarks with corresponding connections.

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
#A function to draw landmarks on the image with customized styles for different body parts, including facial, pose, left hand, and right hand 
#landmarks, each with specified color, thickness, and circle radius.

# %%
#Adding customization options for the style of the drawn landmarks
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
#A script to capture video from a webcam, process it using the Mediapipe Holistic model for human pose estimation, draw styled landmarks on 
#the video feed, and display the processed video in real-time. Press 'q' to exit the program gracefully.

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
len(results.left_hand_landmarks.landmark)

# %%
#A function to extract keypoints from the Mediapipe detection results, including pose, face, left hand, and right hand landmarks. It returns
#a flattened array of keypoints, with each landmark represented by its x, y, z coordinates and visibility. If no landmarks are detected, it 
#returns arrays of zeros with predefined lengths for each body part.

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
#A variable named `result_test` containing the extracted keypoints from the `results` obtained from the Mediapipe detection process.

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.45078254,  0.23680118, -1.35879302, ...,  0.        ,
#         0.        ,  0.        ])

# %%
#Saving the extracted keypoints from the `results` as a NumPy array with filename '0.npy' using `np.save()`, and then loading the saved array 
#back into memory using `np.load()`.

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.45078254,  0.23680118, -1.35879302, ...,  0.        ,
#         0.        ,  0.        ])

# %%
#Defining paths and parameters for the ASL (American Sign Language) dataset, including the directory path for exported data (numpy arrays), 
#the actions to be detected, the number of video sequences, the length of each sequence in frames, and the starting folder index.

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('ASL_V2_Data') 

# Actions that we try to detect
actions = np.array(['Hello', 'Yes', 'Help', 'ThankYou', 'Food', 'Please', 'Finish'])

# Thirty videos worth of data
no_sequences = 120

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
#start_folder = 60

# %%
#A script to create directories for storing data corresponding to different actions and video sequences within the ASL dataset. 
#If the directories don't exist, it creates them based on the defined actions and sequence numbers. If directories already exist, it skips 
#the creation process.

# %%
#Run when you want to append new actions to the directory
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)

for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except FileExistsError:
            pass

# %%
#A script to create directories for storing data corresponding to different actions and video sequences within the ASL dataset. 
#This script should be run only when initially setting up the folders. It attempts to create directories based on the defined actions and 
#sequence numbers, and it skips the creation process if the directories already exist.

# %%
#Only run when creating the folders initially
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
#A script to collect additional videos for a specific action within the ASL dataset. It finds the maximum directory number for the given action,
#increments it, and creates new directories for additional video sequences within that action. If the directories already exist, it skips the 
#creation process.

# %%
#Run when you want to collect additional videos for an action
for action in actions: 
    dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(1,no_sequences+1):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(dirmax+sequence)))
        except:
            pass

# %%
#print(actions[8:])
# Out:
# ['Friend']

# %%
#Collecting keypoints for training and testing
#Captures video from a webcam, performs Mediapipe holistic detection, and collects data for actions defined in the ASL dataset. It iterates 
#through each action and sequence, displaying real-time video with landmarks drawn. It also exports keypoints data for each frame of each 
#sequence into corresponding directories. Press 'q' to exit the program.

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    #for action in actions:
    for action in actions[8:]:
        # Loop through sequences aka videos
        #for sequence in range(start_folder, start_folder+no_sequences):
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
#Preprocessing the data, creating labels, and features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
#Creating a python dictionary `label_map` that maps each action label to a numerical value, with the numerical values assigned based on the order of 
#actions in the `actions` array.

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'Hello': 0,
#  'Yes': 1,
#  'Help': 2,
#  'ThankYou': 3,
#  'Food': 4,
#  'Please': 5,
#  'Finish': 6,
#  'Time': 7,
#  'ILoveYou': 8}

# %%
#This code iterates through each action in the ASL dataset, then for each sequence within that action, it loads the keypoints data for each 
#frame in the sequence. It constructs a window of frames for each sequence and appends it to the `sequences` list, while appending the 
#corresponding label to the `labels` list using the `label_map` dictionary.

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (1080, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (1080,)

# %%
#Converting the list of sequences into NumPy arrays 'X'

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (1080, 30, 1662)

# %%
#This line of code converts the labels array into one-hot encoded format using the `to_categorical` function and then casts the result to an 
#integer type.

# %%
y = to_categorical(labels).astype(int)

# %%
y

# %%
#Splits the data into training and testing sets using a 80-20 ratio

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y_test.shape
# Out:
# (216, 9)

# %%
actions.shape[0]
# Out:
# 9

# %%
#Build and train LSTM neural network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, LeakyReLU
from tensorflow.keras.callbacks import TensorBoard

# %%
#This code creates a directory named "Logs" using `os.path.join`, and then sets up a TensorBoard callback named `tb_callback` to log data to 
#this directory during model training.

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
#This code defines a sequential model using Keras. It consists of three LSTM layers with increasing units, followed by Leaky ReLU activation 
#functions and dropout regularization. Afterward, it includes two dense layers with ReLU activation and a final dense layer with softmax 
#activation for multi-class classification. The model is compiled using the Adam optimizer and categorical cross-entropy loss. 
#It is then trained on the training data (`X_train` and `y_train`) for 120 epochs, with validation data provided (`X_test` and `y_test`), 
#and TensorBoard callback (`tb_callback`) for logging.

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, input_shape=(30, 1662)))
model.add(LeakyReLU(alpha=0.1))  # Leaky ReLU activation
model.add(Dropout(0.5))
model.add(LSTM(128, return_sequences=True))
model.add(LeakyReLU(alpha=0.1))  # Leaky ReLU activation
model.add(Dropout(0.5))
model.add(LSTM(64, return_sequences=False))
model.add(LeakyReLU(alpha=0.1))  # Leaky ReLU activation
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=120, validation_data=(X_test, y_test),callbacks=[tb_callback])
# Out:
# Epoch 1/120
# 27/27 [==============================] - 4s 56ms/step - loss: 2.1489 - accuracy: 0.1644 - val_loss: 1.9744 - val_accuracy: 0.2639
# Epoch 2/120
# 27/27 [==============================] - 1s 22ms/step - loss: 1.9030 - accuracy: 0.3044 - val_loss: 1.9722 - val_accuracy: 0.2269
# Epoch 3/120
# 27/27 [==============================] - 1s 21ms/step - loss: 1.6677 - accuracy: 0.3623 - val_loss: 1.3625 - val_accuracy: 0.4676
# Epoch 4/120
# 27/27 [==============================] - 1s 22ms/step - loss: 1.3270 - accuracy: 0.4144 - val_loss: 1.0966 - val_accuracy: 0.5185
# Epoch 5/120
# 27/27 [==============================] - 1s 22ms/step - loss: 1.4510 - accuracy: 0.3843 - val_loss: 1.3058 - val_accuracy: 0.3009
# Epoch 6/120
# 27/27 [==============================] - 1s 21ms/step - loss: 1.2705 - accuracy: 0.4271 - val_loss: 1.1278 - val_accuracy: 0.5324
# Epoch 7/120
# 27/27 [==============================] - 1s 22ms/step - loss: 1.1825 - accuracy: 0.4259 - val_loss: 1.0363 - val_accuracy: 0.4907
# Epoch 8/120
# 27/27 [==============================] - 1s 22ms/step - loss: 1.0865 - accuracy: 0.4931 - val_loss: 0.9528 - val_accuracy: 0.5139
# Epoch 9/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.9787 - accuracy: 0.5382 - val_loss: 0.8120 - val_accuracy: 0.5880
# Epoch 10/120
# 27/27 [==============================] - 1s 23ms/step - loss: 1.0302 - accuracy: 0.5069 - val_loss: 1.1909 - val_accuracy: 0.4028
# Epoch 11/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.9560 - accuracy: 0.5289 - val_loss: 0.8209 - val_accuracy: 0.5741
# Epoch 12/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.9236 - accuracy: 0.5625 - val_loss: 0.9571 - val_accuracy: 0.4861
# Epoch 13/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.8849 - accuracy: 0.5741 - val_loss: 0.7905 - val_accuracy: 0.6481
# Epoch 14/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.9008 - accuracy: 0.5787 - val_loss: 0.8114 - val_accuracy: 0.6019
# Epoch 15/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.9056 - accuracy: 0.5509 - val_loss: 1.0200 - val_accuracy: 0.5648
# Epoch 16/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.8414 - accuracy: 0.6238 - val_loss: 0.8229 - val_accuracy: 0.5741
# Epoch 17/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.8125 - accuracy: 0.5938 - val_loss: 0.7687 - val_accuracy: 0.6065
# Epoch 18/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.8492 - accuracy: 0.5718 - val_loss: 0.8467 - val_accuracy: 0.5093
# Epoch 19/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.7681 - accuracy: 0.6678 - val_loss: 0.6489 - val_accuracy: 0.6991
# Epoch 20/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.7359 - accuracy: 0.6713 - val_loss: 0.6199 - val_accuracy: 0.7222
# Epoch 21/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.6982 - accuracy: 0.6944 - val_loss: 0.7791 - val_accuracy: 0.6250
# Epoch 22/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.8045 - accuracy: 0.6400 - val_loss: 0.6748 - val_accuracy: 0.6713
# Epoch 23/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.7452 - accuracy: 0.6667 - val_loss: 0.7493 - val_accuracy: 0.6528
# Epoch 24/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.6409 - accuracy: 0.7269 - val_loss: 0.6012 - val_accuracy: 0.7269
# Epoch 25/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.6330 - accuracy: 0.7326 - val_loss: 0.7207 - val_accuracy: 0.6806
# Epoch 26/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.9240 - accuracy: 0.6157 - val_loss: 0.8462 - val_accuracy: 0.5602
# Epoch 27/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.6780 - accuracy: 0.7037 - val_loss: 0.5525 - val_accuracy: 0.7963
# Epoch 28/120
# 27/27 [==============================] - 1s 24ms/step - loss: 0.5657 - accuracy: 0.7812 - val_loss: 0.5415 - val_accuracy: 0.7685
# Epoch 29/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.5610 - accuracy: 0.7882 - val_loss: 0.5043 - val_accuracy: 0.8102
# Epoch 30/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.7795 - accuracy: 0.6597 - val_loss: 0.4950 - val_accuracy: 0.8287
# Epoch 31/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.5272 - accuracy: 0.7917 - val_loss: 0.4899 - val_accuracy: 0.8287
# Epoch 32/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4821 - accuracy: 0.8125 - val_loss: 0.4331 - val_accuracy: 0.8704
# Epoch 33/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.4760 - accuracy: 0.8171 - val_loss: 0.4515 - val_accuracy: 0.8657
# Epoch 34/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.5469 - accuracy: 0.7905 - val_loss: 0.6987 - val_accuracy: 0.7361
# Epoch 35/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.6004 - accuracy: 0.7604 - val_loss: 0.4849 - val_accuracy: 0.8565
# Epoch 36/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.5303 - accuracy: 0.7836 - val_loss: 0.3984 - val_accuracy: 0.8796
# Epoch 37/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4597 - accuracy: 0.8310 - val_loss: 0.3692 - val_accuracy: 0.8889
# Epoch 38/120
# 27/27 [==============================] - 1s 24ms/step - loss: 0.5876 - accuracy: 0.7789 - val_loss: 0.3787 - val_accuracy: 0.8889
# Epoch 39/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.5600 - accuracy: 0.7951 - val_loss: 0.4650 - val_accuracy: 0.8704
# Epoch 40/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.4481 - accuracy: 0.8438 - val_loss: 0.3642 - val_accuracy: 0.8935
# Epoch 41/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3624 - accuracy: 0.8750 - val_loss: 0.3808 - val_accuracy: 0.8843
# Epoch 42/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4700 - accuracy: 0.8252 - val_loss: 0.2623 - val_accuracy: 0.9213
# Epoch 43/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.3725 - accuracy: 0.8727 - val_loss: 0.2594 - val_accuracy: 0.9120
# Epoch 44/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2781 - accuracy: 0.9167 - val_loss: 0.2356 - val_accuracy: 0.9306
# Epoch 45/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2814 - accuracy: 0.8993 - val_loss: 0.2496 - val_accuracy: 0.9259
# Epoch 46/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.2960 - accuracy: 0.8958 - val_loss: 0.2106 - val_accuracy: 0.9306
# Epoch 47/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.2851 - accuracy: 0.8947 - val_loss: 0.2362 - val_accuracy: 0.9352
# Epoch 48/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2857 - accuracy: 0.9005 - val_loss: 0.3207 - val_accuracy: 0.8889
# Epoch 49/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4505 - accuracy: 0.8403 - val_loss: 0.1997 - val_accuracy: 0.9491
# Epoch 50/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3609 - accuracy: 0.8750 - val_loss: 0.6463 - val_accuracy: 0.7963
# Epoch 51/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4718 - accuracy: 0.8183 - val_loss: 0.2824 - val_accuracy: 0.9028
# Epoch 52/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.3568 - accuracy: 0.8519 - val_loss: 0.3274 - val_accuracy: 0.8889
# Epoch 53/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4152 - accuracy: 0.8414 - val_loss: 0.1717 - val_accuracy: 0.9537
# Epoch 54/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2349 - accuracy: 0.9167 - val_loss: 0.2786 - val_accuracy: 0.9074
# Epoch 55/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1822 - accuracy: 0.9421 - val_loss: 0.4699 - val_accuracy: 0.8565
# Epoch 56/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3224 - accuracy: 0.8866 - val_loss: 0.2783 - val_accuracy: 0.9028
# Epoch 57/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2074 - accuracy: 0.9329 - val_loss: 0.2110 - val_accuracy: 0.9444
# Epoch 58/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1730 - accuracy: 0.9468 - val_loss: 0.1297 - val_accuracy: 0.9444
# Epoch 59/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1454 - accuracy: 0.9549 - val_loss: 0.1980 - val_accuracy: 0.9352
# Epoch 60/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.2079 - accuracy: 0.9259 - val_loss: 0.2415 - val_accuracy: 0.9259
# Epoch 61/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1935 - accuracy: 0.9398 - val_loss: 0.1233 - val_accuracy: 0.9583
# Epoch 62/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1216 - accuracy: 0.9664 - val_loss: 0.1747 - val_accuracy: 0.9491
# Epoch 63/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.1670 - accuracy: 0.9375 - val_loss: 0.1952 - val_accuracy: 0.9259
# Epoch 64/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1038 - accuracy: 0.9676 - val_loss: 0.0882 - val_accuracy: 0.9769
# Epoch 65/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1032 - accuracy: 0.9676 - val_loss: 0.1037 - val_accuracy: 0.9583
# Epoch 66/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1202 - accuracy: 0.9572 - val_loss: 0.0857 - val_accuracy: 0.9815
# Epoch 67/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1386 - accuracy: 0.9572 - val_loss: 0.1232 - val_accuracy: 0.9676
# Epoch 68/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1669 - accuracy: 0.9387 - val_loss: 0.2042 - val_accuracy: 0.9352
# Epoch 69/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2112 - accuracy: 0.9352 - val_loss: 0.2898 - val_accuracy: 0.8889
# Epoch 70/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1648 - accuracy: 0.9468 - val_loss: 0.2475 - val_accuracy: 0.9444
# Epoch 71/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1110 - accuracy: 0.9711 - val_loss: 0.1860 - val_accuracy: 0.9398
# Epoch 72/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1719 - accuracy: 0.9444 - val_loss: 0.1158 - val_accuracy: 0.9491
# Epoch 73/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1476 - accuracy: 0.9479 - val_loss: 0.1092 - val_accuracy: 0.9769
# Epoch 74/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.5396 - accuracy: 0.8194 - val_loss: 1.3283 - val_accuracy: 0.6296
# Epoch 75/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.5867 - accuracy: 0.7882 - val_loss: 0.2849 - val_accuracy: 0.9120
# Epoch 76/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1906 - accuracy: 0.9398 - val_loss: 0.1464 - val_accuracy: 0.9537
# Epoch 77/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0898 - accuracy: 0.9792 - val_loss: 0.0942 - val_accuracy: 0.9815
# Epoch 78/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0709 - accuracy: 0.9803 - val_loss: 0.0902 - val_accuracy: 0.9769
# Epoch 79/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0850 - accuracy: 0.9757 - val_loss: 0.1960 - val_accuracy: 0.9398
# Epoch 80/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1312 - accuracy: 0.9537 - val_loss: 0.1265 - val_accuracy: 0.9583
# Epoch 81/120
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1106 - accuracy: 0.9699 - val_loss: 0.1329 - val_accuracy: 0.9630
# Epoch 82/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1226 - accuracy: 0.9630 - val_loss: 0.1512 - val_accuracy: 0.9583
# Epoch 83/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0735 - accuracy: 0.9769 - val_loss: 0.1210 - val_accuracy: 0.9583
# Epoch 84/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.2274 - accuracy: 0.9236 - val_loss: 0.3207 - val_accuracy: 0.8750
# Epoch 85/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2004 - accuracy: 0.9306 - val_loss: 0.1247 - val_accuracy: 0.9537
# Epoch 86/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1209 - accuracy: 0.9641 - val_loss: 0.1307 - val_accuracy: 0.9630
# Epoch 87/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0804 - accuracy: 0.9734 - val_loss: 0.1203 - val_accuracy: 0.9537
# Epoch 88/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0854 - accuracy: 0.9711 - val_loss: 0.1011 - val_accuracy: 0.9676
# Epoch 89/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0542 - accuracy: 0.9826 - val_loss: 0.0998 - val_accuracy: 0.9769
# Epoch 90/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0753 - accuracy: 0.9780 - val_loss: 0.0884 - val_accuracy: 0.9769
# Epoch 91/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0653 - accuracy: 0.9838 - val_loss: 0.0782 - val_accuracy: 0.9861
# Epoch 92/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0888 - accuracy: 0.9688 - val_loss: 0.1095 - val_accuracy: 0.9676
# Epoch 93/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0967 - accuracy: 0.9606 - val_loss: 0.1143 - val_accuracy: 0.9676
# Epoch 94/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1033 - accuracy: 0.9688 - val_loss: 0.0814 - val_accuracy: 0.9769
# Epoch 95/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2784 - accuracy: 0.9109 - val_loss: 0.5062 - val_accuracy: 0.8426
# Epoch 96/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2128 - accuracy: 0.9363 - val_loss: 0.1006 - val_accuracy: 0.9722
# Epoch 97/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0717 - accuracy: 0.9815 - val_loss: 0.0818 - val_accuracy: 0.9815
# Epoch 98/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0514 - accuracy: 0.9861 - val_loss: 0.0746 - val_accuracy: 0.9815
# Epoch 99/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0656 - accuracy: 0.9769 - val_loss: 0.1005 - val_accuracy: 0.9769
# Epoch 100/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0447 - accuracy: 0.9884 - val_loss: 0.0896 - val_accuracy: 0.9769
# Epoch 101/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0649 - accuracy: 0.9803 - val_loss: 0.0959 - val_accuracy: 0.9815
# Epoch 102/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3113 - accuracy: 0.9005 - val_loss: 0.1612 - val_accuracy: 0.9583
# Epoch 103/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1235 - accuracy: 0.9641 - val_loss: 0.1055 - val_accuracy: 0.9722
# Epoch 104/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1332 - accuracy: 0.9606 - val_loss: 0.4063 - val_accuracy: 0.8843
# Epoch 105/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1292 - accuracy: 0.9549 - val_loss: 0.0843 - val_accuracy: 0.9676
# Epoch 106/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0526 - accuracy: 0.9850 - val_loss: 0.0686 - val_accuracy: 0.9861
# Epoch 107/120
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0266 - accuracy: 0.9919 - val_loss: 0.0966 - val_accuracy: 0.9861
# Epoch 108/120
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0247 - accuracy: 0.9942 - val_loss: 0.0896 - val_accuracy: 0.9815
# Epoch 109/120
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0480 - accuracy: 0.9838 - val_loss: 0.1350 - val_accuracy: 0.9676
# Epoch 110/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0537 - accuracy: 0.9815 - val_loss: 0.0782 - val_accuracy: 0.9815
# Epoch 111/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0590 - accuracy: 0.9850 - val_loss: 0.0789 - val_accuracy: 0.9769
# Epoch 112/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.1253 - accuracy: 0.9572 - val_loss: 0.2194 - val_accuracy: 0.9398
# Epoch 113/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0909 - accuracy: 0.9688 - val_loss: 0.0947 - val_accuracy: 0.9769
# Epoch 114/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0542 - accuracy: 0.9792 - val_loss: 0.0671 - val_accuracy: 0.9861
# Epoch 115/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0792 - accuracy: 0.9688 - val_loss: 0.1332 - val_accuracy: 0.9583
# Epoch 116/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0400 - accuracy: 0.9896 - val_loss: 0.0883 - val_accuracy: 0.9815
# Epoch 117/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0964 - accuracy: 0.9688 - val_loss: 0.1988 - val_accuracy: 0.9491
# Epoch 118/120
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0527 - accuracy: 0.9838 - val_loss: 0.0705 - val_accuracy: 0.9861
# Epoch 119/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0185 - accuracy: 0.9954 - val_loss: 0.0727 - val_accuracy: 0.9861
# Epoch 120/120
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0159 - accuracy: 0.9954 - val_loss: 0.0926 - val_accuracy: 0.9815

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  leaky_re_lu (LeakyReLU)     (None, 30, 64)            0
#
#  dropout (Dropout)           (None, 30, 64)            0
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 30, 128)           0
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 9)                 297
#
# =================================================================
# Total params: 596,873
# Trainable params: 596,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Model Predictions

# %%
#Uses the trained model to predict the outputs for the test data `X_test`, storing the predictions in the variable `res`.

# %%
res = model.predict(X_test)

# %%
#Retrieves the action label corresponding to the highest predicted probability from the model's output for the corresponding sample in the test data.

# %%
actions[np.argmax(res[7])]
# Out:
# 'Please'

# %%
#Retrieves the action label corresponding to the highest value in the ground truth labels for the corresponding sample in the test data.

# %%
actions[np.argmax(y_test[7])]
# Out:
# 'Please'

# %%
#Save Weights

# %%
model.save('ASLV7.h5')

# %%
#accuracy_score(ytrue, yhat)

# %%
model = tf.keras.models.load_model('ASLV6.h5')

# %%
#Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
#Uses the trained model to predict the outputs for the test data `X_test`, storing the predictions in the variable `yhat`.

# %%
yhat = model.predict(X_test)

# %%
#This code converts the one-hot encoded ground truth labels `y_test` into their corresponding class indices and stores them in a list 
#named `ytrue`. Similarly, it converts the model predictions `yhat` into their corresponding class indices and stores them in a list
#named `yhat`.

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[193,   2],
#         [  0,  21]],
#
#        [[195,   0],
#         [  0,  21]],
#
#        [[189,   0],
#         [  0,  27]],
#
#        [[193,   2],
#         [  0,  21]],
#
#        [[198,   0],
#         [  1,  17]],
#
#        [[179,   0],
#         [  2,  35]],
#
#        [[196,   0],
#         [  0,  20]],
#
#        [[188,   0],
#         [  0,  28]],
#
#        [[193,   0],
#         [  1,  22]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9814814814814815

# %%
#Test in Real time

# %%
from scipy import stats

# %%
#This script captures video from a webcam and performs real-time detection and prediction of American Sign Language (ASL) gestures using the 
#Mediapipe holistic model and a trained LSTM model. It continuously records 30-frame sequences of keypoint data from the detected poses and 
#feeds them into the LSTM model to predict the corresponding gesture. If the predicted gesture remains consistent for the last 10 predictions 
#and surpasses a certain threshold, it updates the displayed sentence accordingly. Press 'q' to exit the program.

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.8, min_tracking_confidence=0.8) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            #image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Food
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Finish
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Finish
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Finish
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Finish
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Finish
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Finish
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Help
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ThankYou
